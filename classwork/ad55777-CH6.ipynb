# %%
import numpy as np
import time as tm

# %%
def jacobi(A, b, x0, tol, max_iterations):
    
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
            
            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
    return x, max_iterations

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
            # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
    return x, max_iterations

# %%
#In Class Challenge 6a

A = np.array([[10,-1,2,0,0],[-1,11,-1,3,0],[2,-1,10,-1,0],[0,3,-1,8,-2],[0,0,0,-2,9]]) #Creating arrays
b = np.array([14,30,26,25,37])

x0 = np.zeros_like(b)tol = 1e-6 #tolerance
max_iterations = 100

start_time1 = tm.time()

solution, iterations = jacobi(A, b, x0, tol, max_iterations) #Jacobi iterations

end_time1 = tm.time()

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time1 - start_time1} seconds")




start_time2 = tm.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations) #Gauss-seidel iterations

end_time2 = tm.time()

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time2 - start_time2} seconds")


# Converges under both Jacobi and Gauss seidel in 1 and 2 iterations, respectively. The gauss seidel took approx. 0.00031 seconds with jacobi taking approx. 0.00036 seconds.
# Out:
# Solution: [1 2 2 3 4]
# Iterations: 1
# Time: 0.0003597736358642578 seconds
# Solution: [1 2 2 3 4]
# Iterations: 2
# Time: 0.00031304359436035156 seconds

# %%
#In Class Challenge 6b

A = np.array([[1,2,3,0,0],[2,1,2,3,0],[3,2,1,2,3],[0,3,2,1,2],[0,0,3,2,1]]) #Creating arrays
b = np.array([14,22,33,26,22])

x0 = np.zeros_like(b)
tol = 1e-6 #tolerance
max_iterations = 100

start_time1 = tm.time()

solution, iterations = jacobi(A, b, x0, tol, max_iterations) #Jacobi iterations

end_time1 = tm.time()

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time1 - start_time1} seconds")




start_time2 = tm.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations) #Gauss-seidel iterations

end_time2 = tm.time()

print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time2 - start_time2} seconds")


# Does not converge by either Gauss seidel or Jacobi methods of iterations.
# Out:
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# Time: 0.008312225341796875 seconds
# Solution: [-4667072227903264768 -5861557759596381184  5941495520527654912
#     32542205762157592   557173100602271744]
# Iterations: 100
# Time: 0.007608652114868164 seconds
# <ipython-input-2-14c663fdff0b>:10: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-3-a9900344b847>:11: RuntimeWarning: overflow encountered in long_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# <ipython-input-3-a9900344b847>:12: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]
