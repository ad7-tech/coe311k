# %% [markdown]
# This is my very first notebook.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
numIn = str(5)
myfile = open("test.dat", 'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("HelloWorld")
myfile.close()
