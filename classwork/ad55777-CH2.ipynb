# %%
import numpy as np

def tobase2(x):
    bits = []
    while(x>0):
        bits.append(x % 2)
        x = x//2

# returnoing the reverse the numbers to get binary
    return np.array(bits[::-1])        
        
tobase2(2025)
# Out:
# array([1, 1, 1, 1, 1, 1, 0, 1, 0, 0, 1])
