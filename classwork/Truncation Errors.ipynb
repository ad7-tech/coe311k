# %% [markdown]
# Truncation Errors arise when an infinite process (like series or pi) is approximated by a finite proces.
# This occurs when you truncate a mathematical procedure, such as integration, etc...

# %% [markdown]
# Leibniz Series for pi
#
# pi/4 = sum from 0 to infinity ((-1)^n/(2n+1))
