# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')

# Generate new x values for a smooth plot
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

# %%
# Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data
degree = 3

coefficients = np.polyfit(x, y, degree)

# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 0.07407407 -0.55555556  1.1005291   0.06349206]

# %%
# Plot the original data and cubic spline interpolation

y_pred = polynomial(x_interp)

plt.plot(x, y, 'bo', label="Data points")
plt.plot(x_interp, y_interp, 'r-', label="Cubic Spline Interpolation")
plt.plot(x_interp, y_pred, color='green', label=f'Polynomial fit of degree {degree}')
plt.title("Cubic Spline Interpolation")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# By calculating the polyfit with degree 3 and comparing that to the calculation of the cubic spline interpolation, we can see that the poly fit doesnt nearly fit the data as well as the cubic spline interpolation. The cubic spline interpolation is also more of a sin curve, whereas the polyfit is a cubic curve, likely meaning that cubic spline will represent future data better.
